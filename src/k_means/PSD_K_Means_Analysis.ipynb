# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy import signal
from scipy import constants
import os
import glob
from matplotlib import rc
from sklearn.metrics import mean_squared_error

# %%
from InfluxData import InfluxData
client = InfluxData()
client.set_client('155.230.28.170',8086,'sslab','1231',database='kmaeq')
device_ids = client.get_device()

# %%
raw_data = {'dev_id':[],
            'Mean_PSD_x':[],
            'Mean_PSD_y':[],
            'Mean_PSD_z':[],
            'MSE_PSD_x':[],
            'MSE_PSD_y':[],
            'MSE_PSD_z':[]}
new_df = pd.DataFrame(raw_data)
new_df
# Out:
# Empty DataFrame
# Columns: [dev_id, Mean_PSD_x, Mean_PSD_y, Mean_PSD_z, MSE_PSD_x, MSE_PSD_y, MSE_PSD_z]
# Index: []

# %%
EXPECT_DATASET_SIZE = 60000 # 10min data
def psd_processing(dev_id:str):
    cli = InfluxData()
    cli.set_client('155.230.28.170',8086,'sslab','1231',database='kmaeq')
    rs = cli.query(f"select * from acc_data where dev_id='{dev_id}' and time >= now() -40m AND time <= now() - 30m")
    data = cli.resultSetToDF(rs)
    if type(data['acc_data']) is list: #  it means empty data
        print('empty data')
        return dev_id
    if len(data['acc_data']) < EXPECT_DATASET_SIZE*0.9: # not enough data size
        print('not enough data size')
        return dev_id
    data = data['acc_data'] # convert dict_dataframe to dataframe
    x = data['x']*constants.g
    y = data['y']*constants.g
    z = data['z']*constants.g
    offset_x = x - np.mean(x)
    offset_y = y - np.mean(y)
    offset_z = z - np.mean(z)
    Pxx, freqs_x = plt.psd(offset_x,NFFT=200,Fs=100)
    Pxx_true = [0 for i in range(len(Pxx))]
    x_mse = mean_squared_error(Pxx,Pxx_true)
    Pyy, freqs_y = plt.psd(offset_y,NFFT=200,Fs=100)
    Pyy_true = [0 for i in range(len(Pyy))]
    y_mse = mean_squared_error(Pyy,Pyy_true)
    Pzz, freqs_z = plt.psd(offset_z,NFFT=200,Fs=100)
    Pzz_true = [0 for i in range(len(Pzz))]
    z_mse = mean_squared_error(Pzz,Pzz_true)
    row = {'dev_id':dev_id,
            'Mean_PSD_x':np.mean(Pxx),
            'Mean_PSD_y':np.mean(Pyy),
            'Mean_PSD_z':np.mean(Pzz),
            'MSE_PSD_x': x_mse,
            'MSE_PSD_y': y_mse,
            'MSE_PSD_z': z_mse
            }
    return row

# %%
# %%time
from concurrent.futures import ProcessPoolExecutor, as_completed, wait
pool = ProcessPoolExecutor(len(device_ids))
futures = []
for dev_id in device_ids:
    futures.append(pool.submit(psd_processing,dev_id))

err_devices = [] 

for x in as_completed(futures,timeout=120):
    if type(x.result()) is dict:
        new_df = new_df.append(x.result(),ignore_index=True)
    else:
        err_devices.append(x.result())
# Out:
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# not enough data size
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# empty data
# not enough data size
# empty data
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# not enough data size
# CPU times: user 952 ms, sys: 1.77 s, total: 2.72 s
# Wall time: 20.4 s

# %%
'''
while(q.empty() is False):
    new_df = new_df.append(q.get(),ignore_index=True)
new_df
'''
new_df
#new_df['Mean_PSD_x'].describe()
# Out:
#     dev_id    Mean_PSD_x    Mean_PSD_y    Mean_PSD_z     MSE_PSD_x  \
# 0     0255  8.827718e-07  1.641519e-06  1.652955e-06  7.878389e-13
# 1     0018  1.870599e-06  2.000780e-06  2.067574e-06  3.542849e-12
# 2     0048  1.764921e-06  2.162331e-06  1.790383e-06  3.148519e-12
# 3     0111  6.706694e-06  2.695953e-06  3.913300e-06  9.208878e-10
# 4     0064  1.431192e-06  2.788349e-08  2.686720e-06  2.065438e-12
# 5     0108  2.008229e-06  1.223919e-07  5.146783e-06  1.039424e-11
# 6     0057  1.814079e-06  2.023327e-06  2.582971e-06  3.319623e-12
# 7     0091  6.018343e-06  2.069068e-06  6.777270e-06  7.720015e-10
# 8     0026  1.877381e-06  2.285492e-06  2.581975e-06  3.618173e-12
# 9     0102  1.961687e-06  2.055558e-06  2.535733e-06  3.977242e-12
# 10    0031  1.717169e-06  2.119806e-06  2.644508e-06  2.973758e-12
# 11    0146  1.605985e-06  2.069942e-06  2.049748e-06  2.599932e-12
# 12    0110  2.200055e-06  2.366141e-06  2.059353e-06  4.928456e-12
# 13    0116  3.007134e-06  1.278044e-06  2.942199e-05  1.801315e-11
# 14    0065  1.290047e-06  2.490093e-06  2.592873e-06  1.747745e-12
# 15    0024  8.732616e-07  3.976747e-06  5.893191e-06  1.967466e-11
# 16    0078  1.692927e-06  1.639308e-06  6.085946e-06  3.138052e-12
# 17    0040  1.820076e-06  1.342304e-06  2.168960e-06  3.341593e-12
# 18    0032  2.381939e-06  2.253064e-06  2.246442e-06  5.914134e-12
# 19    0047  2.024610e-06  2.161059e-06  2.655246e-06  4.158004e-12
# 20    0135  1.762469e-06  1.749821e-06  2.000449e-06  3.182602e-12
# 21    0015  2.035590e-06  2.828223e-07  2.109203e-06  4.373702e-12
# 22    0037  2.162340e-06  6.190219e-07  1.792636e-06  4.747453e-12
# 23    0131  2.071368e-06  2.159004e-06  2.034031e-06  4.383551e-12
# 24    0100  2.981261e-06  2.437585e-06  2.513095e-06  2.217402e-11
# 25    0027  1.402606e-07  2.240571e-06  1.814311e-06  2.010819e-14
# 26    0073  2.174884e-06  2.188642e-06  4.172651e-06  4.798020e-12
# 27    0112  2.585213e-06  2.220437e-06  4.010592e-06  7.578244e-12
# 28    0106  3.235770e-06  3.726010e-06  4.683558e-06  8.953347e-11
# 29    0055  1.274574e-06  1.962487e-06  5.518500e-06  1.658844e-12
# ..     ...           ...           ...           ...           ...
# 151   0235  1.683594e-06  2.032427e-06  2.635852e-06  2.871219e-12
# 152   0261  1.573436e-06  1.394842e-06  1.479258e-07  2.629610e-12
# 153   0213  1.599066e-06  1.719745e-06  2.400035e-06  2.717838e-12
# 154   0061  1.716584e-06  7.100191e-07  2.379342e-06  3.200011e-12
# 155   0163  1.718856e-06  1.791019e-06  2.043658e-06  3.130829e-12
# 156   0124  1.758720e-06  1.863597e-06  1.847470e-06  3.279412e-12
# 157   0132  8.470060e-06  3.226829e-06  4.542177e-05  1.085155e-09
# 158   0175  1.837533e-06  2.137174e-06  2.169779e-06  3.445798e-12
# 159   0120  1.764126e-06  1.937175e-06  2.300792e-06  3.317857e-12
# 160   0284  5.501120e-07  1.878754e-06  2.313045e-06  3.220179e-13
# 161   0107  1.934164e-06  2.291658e-06  2.002685e-06  4.000941e-12
# 162   0034  2.024306e-06  2.428072e-06  2.486749e-06  4.675889e-12
# 163   0185  1.554242e-06  1.734068e-06  1.816465e-06  2.561403e-12
# 164   0186  1.662304e-06  8.585774e-07  1.708656e-06  3.048896e-12
# 165   0114  2.005250e-06  2.017964e-06  3.089231e-06  4.340029e-12
# 166   0145  1.835477e-06  1.782104e-06  2.303480e-06  3.598273e-12
# 167   0162  1.918300e-06  1.945775e-06  1.777890e-06  3.939549e-12
# 168   0263  1.688919e-06  1.344493e-06  1.312476e-07  3.019776e-12
# 169   0279  1.748181e-06  1.877228e-06  2.314010e-06  3.253693e-12
# 170   0060  1.724561e-06  2.014679e-06  1.775141e-06  3.153862e-12
# 171   0098  1.754229e-06  1.849096e-06  1.625268e-06  3.284816e-12
# 172   0136  2.080674e-06  1.752764e-06  1.986020e-06  4.850017e-12
# 173   0030  2.054188e-06  1.231597e-07  5.606885e-06  1.057645e-11
# 174   0239  1.932368e-06  2.116149e-06  7.226175e-06  3.822317e-12
# 175   0101  1.237658e-06  6.507353e-08  1.906322e-06  1.635494e-12
# 176   0233  1.576269e-06  1.153379e-06  3.037598e-06  2.507740e-12
# 177   0176  1.300464e-06  1.957463e-06  1.832364e-06  1.803845e-12
# 178   0144  1.461670e-06  1.449474e-07  1.693423e-06  2.264328e-12
# 179   0285  1.332997e-06  9.415238e-08  2.145445e-06  1.879593e-12
# 180   0198  1.598788e-06  1.447755e-06  1.651893e-06  2.709720e-12
#
#         MSE_PSD_y     MSE_PSD_z
# 0    2.729716e-12  4.113090e-12
# 1    4.067052e-12  5.029059e-12
# 2    4.762619e-12  3.387594e-12
# 3    2.891341e-11  7.044334e-11
# 4    7.843010e-16  7.925486e-12
# 5    1.742236e-14  1.711621e-10
# 6    4.128599e-12  7.422962e-12
# 7    4.990878e-12  6.637938e-10
# 8    5.402540e-12  1.197720e-11
# 9    4.330157e-12  6.667591e-12
# 10   4.540587e-12  8.062584e-12
# 11   4.421919e-12  4.928616e-12
# 12   5.658566e-12  4.317682e-12
# 13   2.643369e-12  9.685451e-09
# 14   7.162475e-12  2.143306e-11
# 15   1.329522e-10  1.660474e-10
# 16   2.979757e-12  1.723879e-10
# 17   1.815724e-12  4.827983e-12
# 18   5.246476e-12  5.345382e-12
# 19   4.708427e-12  7.767695e-12
# 20   3.158543e-12  7.158614e-12
# 21   8.045348e-14  4.516524e-12
# 22   3.878342e-13  3.250008e-12
# 23   4.764361e-12  4.213596e-12
# 24   9.080083e-12  1.289905e-11
# 25   5.081874e-12  3.965835e-12
# 26   4.828558e-12  1.361157e-10
# 27   5.537975e-12  3.280293e-11
# 28   1.445297e-10  2.221336e-10
# 29   3.922535e-12  7.640603e-10
# ..            ...           ...
# 151  4.194868e-12  7.538407e-12
# 152  2.070824e-12  2.337477e-14
# 153  3.146580e-12  7.167885e-12
# 154  5.560110e-13  6.205852e-12
# 155  3.406203e-12  4.431680e-12
# 156  3.680831e-12  3.620246e-12
# 157  2.291730e-11  2.651694e-08
# 158  4.658497e-12  4.856073e-12
# 159  4.022502e-12  5.666991e-12
# 160  3.772542e-12  7.016539e-12
# 161  5.617690e-12  4.343097e-12
# 162  6.670950e-12  6.863990e-12
# 163  3.176566e-12  3.491836e-12
# 164  7.856276e-13  3.103694e-12
# 165  4.421675e-12  1.326371e-11
# 166  4.057120e-12  6.092215e-12
# 167  4.078183e-12  3.381888e-12
# 168  1.918739e-12  1.824552e-14
# 169  3.749737e-12  5.831955e-12
# 170  4.311706e-12  3.361297e-12
# 171  3.672801e-12  2.845872e-12
# 172  3.304824e-12  4.318725e-12
# 173  1.587740e-14  1.675265e-10
# 174  4.637593e-12  1.270251e-10
# 175  4.519816e-15  3.865320e-12
# 176  1.418293e-12  5.511854e-11
# 177  4.052825e-12  3.566268e-12
# 178  2.237997e-14  3.159215e-12
# 179  9.424153e-15  5.005573e-12
# 180  2.223273e-12  2.886236e-12
#
# [181 rows x 7 columns]

# %%
cant_qry = set(device_ids) - set(err_devices) - set(new_df['dev_id'])
cant_qry
# Out:
# set()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure()
ax = plt.gca(projection='3d')
ax.scatter(new_df['Mean_PSD_x'],new_df['Mean_PSD_y'],new_df['Mean_PSD_z'])
ax.set_xlim(-0.005,0.02)
ax.set_ylim(-0.005,0.02)
ax.set_zlim(-0.005,0.02)
plt.show()

# %%
from sklearn.cluster import KMeans
dev_id = new_df['dev_id']
Feature = new_df.loc[:,new_df.columns != 'dev_id']

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
#ss = StandardScaler()
#ss = MinMaxScaler()
ss = RobustScaler()
ss.fit(Feature)
Feature = ss.transform(Feature)
Feature
fig = plt.figure()
ax = plt.gca(projection='3d')
ax.scatter(Feature[:][0],Feature[:][1],Feature[:][2])
'''
ax.set_xlim(-0.09,-0.07)
ax.set_ylim(-0.09,-0.07)
ax.set_zlim(-0.09,-0.07)
'''
'''
ax.set_xlim(-0.001,0.001)
ax.set_ylim(-0.001,0.001)
ax.set_zlim(-0.001,0.001)
'''
ax.set_xlim(-1.1,0.6)
ax.set_ylim(-1.1,0.6)
ax.set_zlim(-1.1,0.6)
plt.show()

# %%
# Out:
# (181, 6)

# %%
kmeans = KMeans(n_clusters=6).fit(Feature)
kmeans_labels = kmeans.labels_
kmeans_results = pd.concat([dev_id,pd.DataFrame(kmeans_labels.reshape(-1,1),columns=['prediction'])],axis=1)
kmeans_outliers = kmeans_results.loc[kmeans_results['prediction'] != 0]

# %%
ks = range(1,10)
inertias = []
for k in ks:
    model = KMeans(n_clusters=k).fit(Feature)
    inertias.append(model.inertia_)

plt.plot(ks,inertias,'-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertias')
plt.xticks(ks)
plt.show()

# %%
kmeans_outliers
# Out:
#     dev_id  prediction
# 26    0249           5
# 45    0011           4
# 85    0211           3
# 127   0064           2
# 156   0025           1

# %%
np.save('PSD_k-means_center.npy',kmeans.cluster_centers_)
kmeans.cluster_centers_
# Out:
# array([[-0.08841661, -0.08960932, -0.0911136 , -0.07274193, -0.07396849,
#         -0.07376685],
#        [13.94729408, 13.82374913, 13.83905212, 14.13802406, 14.12936032,
#         14.13168501],
#        [ 2.05615889,  2.77235021,  2.65696301,  0.26696622,  0.52755617,
#          0.47036151],
#        [ 0.66614311,  0.78873463,  0.67500959, -0.03177797, -0.01613233,
#         -0.03136693],
#        [ 0.48577204,  0.09206701,  0.56384412, -0.04844807, -0.07127309,
#         -0.04209844],
#        [ 0.17428766,  0.08652542,  0.12339693, -0.06734588, -0.0716866 ,
#         -0.07027949]])

# %%
kmeans_test = KMeans(n_clusters=6)
kmeans_test.cluster_centers_ = kmeans.cluster_centers_
type(kmeans_test.cluster_centers_)
# Out:
# numpy.ndarray

# %%
kmeans_test_label = kmeans_test.predict(Feature)
kmeans_test_result = pd.concat([dev_id,pd.DataFrame(kmeans_test_label.reshape(-1,1),columns=['prediction'])],axis=1)
kmeans_test_result
kmeans_test_outliers = kmeans_test_result.loc[kmeans_results['prediction'] !=0]
kmeans_test_outliers
# Out:
#     dev_id  prediction
# 26    0249           5
# 45    0011           4
# 85    0211           3
# 127   0064           2
# 156   0025           1
